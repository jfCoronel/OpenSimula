# %% [markdown]
# ## EDIFICIO CURSO ATECYR HULC
#
# Edificio importado desde HULC, es el edificio que usamos como pequeño terciario en los CURSOS de ATECYR.

# %%
import opensimula as osm

sim = osm.Simulation()
pro = sim.new_project("pro")
pro.read_json("edificio_curso_hulc.json")
# Out:
# Reading project data from file: edificio_curso_hulc.json
# Reading completed.
# Checking project: Edificio_curso_hulc
# Checking completed.

# %%
import datetime as dt

date = dt.datetime(2001,3,21,19,0,0)
#pro.show_3D(jupyter=True)
pro.show_3D_shadows(date,jupyter=True)
#pro.show_3D_shadows_animation(date,jupyter=True)

# %%
pro.parameter("shadow_calculation").value= "INTERPOLATION"
pro.simulate()
# 30s calculando las sombras de directa
# 4m:55s Simulando con shadow_calculation = INSTANT, n_iter = 4
# 1m:21s Simulando con shadow_calculation = INTERPOLATION, n_iter = 4
# Out:
# Calculating solar direct shadows ...
# Simulating Edificio_curso_hulc: ...
# 100%|██████████| 8760/8760 [01:21<00:00, 107.36step/s, n_iter=4]

# %%
pro
# Out:
# <h3>Project: Edificio_curso_hulc</h3><p>Description of the project</p><strong>Parameters:</strong><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>key</th>
#       <th>type</th>
#       <th>value</th>
#       <th>unit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>name</td>
#       <td>Parameter_string</td>
#       <td>Edificio_curso_hulc</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>description</td>
#       <td>Parameter_string</td>
#       <td>Description of the project</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>time_step</td>
#       <td>Parameter_int</td>
#       <td>3600</td>
#       <td>s</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>n_time_steps</td>
#       <td>Parameter_int</td>
#       <td>8760</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>initial_time</td>
#       <td>Parameter_string</td>
#       <td>01/01/2001 00:00:00</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>daylight_saving</td>
#       <td>Parameter_boolean</td>
#       <td>False</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>daylight_saving_start_time</td>
#       <td>Parameter_string</td>
#       <td>25/03/2001 02:00:00</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>daylight_saving_end_time</td>
#       <td>Parameter_string</td>
#       <td>28/10/2001 02:00:00</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>n_max_iteration</td>
#       <td>Parameter_int</td>
#       <td>1000</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>simulation_order</td>
#       <td>Parameter_string_list</td>
#       <td>[Space_type, Building_surface, Solar_surface, Opening, Space, Building, HVAC_MZW_system, HVAC_perfect_system, HVAC_DX_system, HVAC_SZW_system, HVAC_water_system, Calculator]</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>simulation_file_met</td>
#       <td>Parameter_component</td>
#       <td>Sevilla</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>shadow_calculation</td>
#       <td>Parameter_options</td>
#       <td>INSTANT</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>albedo</td>
#       <td>Parameter_float</td>
#       <td>0.2</td>
#       <td>frac</td>
#     </tr>
#   </tbody>
# </table><br/><strong>Components list:</strong><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>type</th>
#       <th>description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Tabicón de LH doble [60 mm &lt; E &lt; 90 mm]</td>
#       <td>Material</td>
#       <td>Material layer properties</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Material_Base</td>
#       <td>Material</td>
#       <td>Material layer properties</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Teja cerámica-porcelana</td>
#       <td>Material</td>
#       <td>Material layer properties</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>FU Entrevigado de EPS moldeado descolgado -Canto 250 mm</td>
#       <td>Material</td>
#       <td>Material layer properties</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>FU Entrevigado de EPS moldeado descolgado -Canto 300 mm</td>
#       <td>Material</td>
#       <td>Material layer properties</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>FU Entrevigado de EPS moldeado descolgado -Canto 350 mm</td>
#       <td>Material</td>
#       <td>Material layer properties</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>FR Entrevigado de EPS moldeado descolgado -Canto 300 mm</td>
#       <td>Material</td>
#       <td>Material layer properties</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>FR Entrevigado de EPS moldeado descolgado -Canto 350 mm</td>
#       <td>Material</td>
#       <td>Material layer properties</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>FR Entrevigado de EPS moldeado descolgado -Canto 400 mm</td>
#       <td>Material</td>
#       <td>Material layer properties</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>FR Entrevigado de EPS moldeado descolgado -Canto 450 mm</td>
#       <td>Material</td>
#       <td>Material layer properties</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>1/2 pie LM métrico o catalán 40 mm&lt; G &lt; 50 mm</td>
#       <td>Material</td>
#       <td>Material layer properties</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>1/2 pie LP métrico o catalán 40 mm&lt; G &lt; 60 mm</td>
#       <td>Material</td>
#       <td>Material layer properties</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>Betún fieltro o lámina</td>
#       <td>Material</td>
#       <td>Material layer properties</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>Conífera de peso medio 435 &lt; d &lt; 520</td>
#       <td>Material</td>
#       <td>Material layer properties</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>Cámara de aire sin ventilar horizontal 10 cm</td>
#       <td>Material</td>
#       <td>Material layer properties</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>Cámara de aire sin ventilar horizontal 5 cm</td>
#       <td>Material</td>
#       <td>Material layer properties</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>Cámara de aire sin ventilar vertical 5 cm</td>
#       <td>Material</td>
#       <td>Material layer properties</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>EPS Poliestireno Expandido [ 0.037 W/[mK]]</td>
#       <td>Material</td>
#       <td>Material layer properties</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>Enlucido de yeso 1000 &lt; d &lt; 1300</td>
#       <td>Material</td>
#       <td>Material layer properties</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>FU Entrevigado de hormigón aligerado -Canto 250 mm</td>
#       <td>Material</td>
#       <td>Material layer properties</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>FU Entrevigado de hormigón aligerado -Canto 300 mm</td>
#       <td>Material</td>
#       <td>Material layer properties</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>Hormigón armado 2300 &lt; d &lt; 2500</td>
#       <td>Material</td>
#       <td>Material layer properties</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>Mortero de cemento o cal para albañilería y para revoco/enlucido 1250 &lt; d &lt; 1450</td>
#       <td>Material</td>
#       <td>Material layer properties</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>Mortero de áridos ligeros [vermiculita perlita]</td>
#       <td>Material</td>
#       <td>Material layer properties</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>Mármol [2600 &lt; d &lt; 2800]</td>
#       <td>Material</td>
#       <td>Material layer properties</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>Tabique de LH sencillo [40 mm &lt; Espesor &lt; 60 mm]</td>
#       <td>Material</td>
#       <td>Material layer properties</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>Teja de arcilla cocida</td>
#       <td>Material</td>
#       <td>Material layer properties</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>Tierra apisonada adobe bloques de tierra comprimida [1770 &lt; d &lt; 2000]</td>
#       <td>Material</td>
#       <td>Material layer properties</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>MADERA_PUERTA_OPACA</td>
#       <td>Material</td>
#       <td>Material layer properties</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>VER_DC_4-6-6</td>
#       <td>Glazing</td>
#       <td>Glazing material.</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>HOR_DC_4-6-6</td>
#       <td>Glazing</td>
#       <td>Glazing material.</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>Met - Gris claro</td>
#       <td>Frame</td>
#       <td>Opening frame</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>Mrpt - Gris claro</td>
#       <td>Frame</td>
#       <td>Opening frame</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>Mpvc o mad - Gris claro</td>
#       <td>Frame</td>
#       <td>Opening frame</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>VER_Madera de densidad media alta</td>
#       <td>Frame</td>
