# %% [markdown]
# ## EDIFICIO EJEMPLO HULC
#
# Edificio importado desde HULC, es uno de los ejemplos de la documentación de HULC.

# %%
import opensimula as osm

dic = {
  "name": "Vivienda ejemplo 1",
  "time_step": 3600,
  "n_time_steps": 8760,
  "initial_time": "01/01/2001 00:00:00",
  "simulation_file_met": "Sevilla",
  "components": [
    {
      "type": "Material",
      "name": "Material_Base",
      "conductivity": 1.0,
      "density": 3000.0,
      "specific_heat": 1000.0
    },
    {
      "type": "Material",
      "name": "Teja cerámica-porcelana",
      "conductivity": 1.3,
      "density": 2300.0,
      "specific_heat": 840.0
    },
    {
      "type": "Material",
      "name": "FU Entrevigado de EPS moldeado descolgado -Canto 250 mm",
      "conductivity": 0.1760563,
      "density": 710.0,
      "specific_heat": 1000.0
    },
    {
      "type": "Material",
      "name": "FU Entrevigado de EPS moldeado descolgado -Canto 300 mm",
      "conductivity": 0.2,
      "density": 670.0,
      "specific_heat": 1000.0
    },
    {
      "type": "Material",
      "name": "FU Entrevigado de EPS moldeado descolgado -Canto 350 mm",
      "conductivity": 0.2229299,
      "density": 640.0,
      "specific_heat": 1000.0
    },
    {
      "type": "Material",
      "name": "FR Entrevigado de EPS moldeado descolgado -Canto 300 mm",
      "conductivity": 0.3571429,
      "density": 1330.0,
      "specific_heat": 1000.0
    },
    {
      "type": "Material",
      "name": "FR Entrevigado de EPS moldeado descolgado -Canto 350 mm",
      "conductivity": 0.4022988,
      "density": 1310.0,
      "specific_heat": 1000.0
    },
    {
      "type": "Material",
      "name": "FR Entrevigado de EPS moldeado descolgado -Canto 400 mm",
      "conductivity": 0.4395604,
      "density": 1290.0,
      "specific_heat": 1000.0
    },
    {
      "type": "Material",
      "name": "FR Entrevigado de EPS moldeado descolgado -Canto 450 mm",
      "conductivity": 0.4787234,
      "density": 1280.0,
      "specific_heat": 1000.0
    },
    {
      "type": "Material",
      "name": "1 pie LP métrico o catalán 40 mm< G < 60 mm",
      "conductivity": 0.667,
      "density": 1220.0,
      "specific_heat": 1000.0
    },
    {
      "type": "Material",
      "name": "Arena y grava [1700 < d < 2200]",
      "conductivity": 2.0,
      "density": 1450.0,
      "specific_heat": 1050.0
    },
    {
      "type": "Material",
      "name": "Betún fieltro o lámina",
      "conductivity": 0.23,
      "density": 1100.0,
      "specific_heat": 1000.0
    },
    {
      "type": "Material",
      "name": "Cloruro de polivinilo [PVC]",
      "conductivity": 0.17,
      "density": 1390.0,
      "specific_heat": 900.0
    },
    {
      "type": "Material",
      "name": "Cámara de aire sin ventilar horizontal 5 cm",
      "use_resistance": True,
      "thermal_resistance": 0.16
    },
    {
      "type": "Material",
      "name": "EPS Poliestireno Expandido [ 0.037 W/[mK]]",
      "conductivity": 0.0375,
      "density": 30.0,
      "specific_heat": 1000.0
    },
    {
      "type": "Material",
      "name": "FU Entrevigado cerámico -Canto 250 mm",
      "conductivity": 0.908,
      "density": 1220.0,
      "specific_heat": 1000.0
    },
    {
      "type": "Material",
      "name": "FU Entrevigado de EPS mecanizado enrasado -Canto 250 mm",
      "conductivity": 0.266,
      "density": 800.0,
      "specific_heat": 1000.0
    },
    {
      "type": "Material",
      "name": "FU Entrevigado de EPS mecanizado enrasado -Canto 300 mm",
      "conductivity": 0.256,
      "density": 750.0,
      "specific_heat": 1000.0
    },
    {
      "type": "Material",
      "name": "Hormigón en masa 2000 < d < 2300",
      "conductivity": 1.65,
      "density": 2150.0,
      "specific_heat": 1000.0
    },
    {
      "type": "Material",
      "name": "MW Lana mineral [0.04 W/[mK]]",
      "conductivity": 0.0405,
      "density": 40.0,
      "specific_heat": 1000.0
    },
    {
      "type": "Material",
      "name": "Mortero de cemento o cal para albañilería y para revoco/enlucido 1000 < d < 1250",
      "conductivity": 0.55,
      "density": 1125.0,
      "specific_heat": 1000.0
    },
    {
      "type": "Material",
      "name": "Placa de yeso laminado [PYL] 750 < d < 900",
      "conductivity": 0.25,
      "density": 825.0,
      "specific_heat": 1000.0
    },
    {
      "type": "Material",
      "name": "Plaqueta o baldosa de gres",
      "conductivity": 2.3,
      "density": 2500.0,
      "specific_heat": 1000.0
    },
    {
      "type": "Material",
      "name": "Teja de arcilla cocida",
      "conductivity": 1.0,
      "density": 2000.0,
      "specific_heat": 800.0
    },
    {
      "type": "Material",
      "name": "XPS Expandido con dióxido de carbono CO2 [ 0.034 W/[mK]]",
      "conductivity": 0.034,
      "density": 37.5,
      "specific_heat": 1000.0
    },
    {
      "type": "Material",
      "name": "cv_hor_asc",
      "use_resistance": True,
      "thermal_resistance": 0.06
    },
    {
      "type": "Glazing",
      "name": "VIRDIO NORTE",
      "solar_tau": 0.6244,
      "g": [
        0.6244,
        0.6244
      ],
      "U": 1.0,
      "solar_rho": [
        0.1,
        0.1
      ],
      "lw_epsilon": [
        0.84,
        0.84
      ]
    },
    {
      "type": "Glazing",
      "name": "VIDRIO SUR",
      "solar_tau": 0.4299,
      "g": [
        0.4299,
        0.4299
      ],
      "U": 1.0,
      "solar_rho": [
        0.1,
        0.1
      ],
      "lw_epsilon": [
        0.84,
        0.84
      ]
    },
    {
      "type": "Glazing",
      "name": "VER_DC_4-12-4",
      "solar_tau": 0.7676,
      "g": [
        0.7676,
        0.7676
      ],
      "U": 2.8,
      "solar_rho": [
        0.1,
        0.1
      ],
      "lw_epsilon": [
        0.84,
        0.84
      ]
    },
    {
      "type": "Frame",
      "name": "Met - Gris claro",
      "thermal_resistance": 0.1754,
      "solar_alpha": [
        0.4,
        0.4
      ]
    },
    {
      "type": "Frame",
      "name": "Mrpt - Gris claro",
      "thermal_resistance": 0.3125,
      "solar_alpha": [
        0.4,
        0.4
      ]
    },
    {
      "type": "Frame",
      "name": "Mpvc o mad - Gris claro",
      "thermal_resistance": 0.4545,
      "solar_alpha": [
        0.4,
        0.4
      ]
    },
    {
      "type": "Frame",
      "name": "MARCO PVC PROPIO",
      "thermal_resistance": 0.6667,
      "solar_alpha": [
        0.3,
        0.3
      ]
    },
    {
      "type": "Frame",
      "name": "HOR_Madera de densidad media alta",
      "thermal_resistance": 0.4167,
      "solar_alpha": [
        0.7,
        0.7
      ]
    },
    {
      "type": "Frame",
      "name": "VER_Madera de densidad media alta",
      "thermal_resistance": 0.4545,
      "solar_alpha": [
        0.7,
        0.7
      ]
    },
    {
      "type": "Construction",
      "name": "CUBIERTA INCLINADA",
      "materials": [
        "Teja de arcilla cocida",
        "cv_hor_asc",
        "XPS Expandido con dióxido de carbono CO2 [ 0.034 W/[mK]]",
        "Betún fieltro o lámina",
        "FU Entrevigado de EPS mecanizado enrasado -Canto 250 mm",
        "Placa de yeso laminado [PYL] 750 < d < 900"
      ],
      "thicknesses": [
        0.015,
        0.05,
        0.16,
        0.01,
        0.25,
        0.015
      ],
      "solar_alpha": [
        0.6,
        0.6
      ],
      "lw_epsilon": [
        0.9,
        0.9
      ]
    },
    {
      "type": "Construction",
      "name": "FORJADO CON CAMARA SANITARIA",
      "materials": [
        "Plaqueta o baldosa de gres",
        "Mortero de cemento o cal para albañilería y para revoco/enlucido 1000 < d < 1250",
        "Mortero de cemento o cal para albañilería y para revoco/enlucido 1000 < d < 1250",
        "XPS Expandido con dióxido de carbono CO2 [ 0.034 W/[mK]]",
        "FU Entrevigado de EPS mecanizado enrasado -Canto 300 mm"
      ],
      "thicknesses": [
        0.01,
        0.025,
        0.065,
        0.1,
        0.3
      ],
      "solar_alpha": [
        0.6,
        0.6
      ],
      "lw_epsilon": [
        0.9,
        0.9
      ]
    },
    {
      "type": "Construction",
      "name": "FORJADO INTERIOR",
      "materials": [
        "Plaqueta o baldosa de gres",
        "Mortero de cemento o cal para albañilería y para revoco/enlucido 1000 < d < 1250",
        "Mortero de cemento o cal para albañilería y para revoco/enlucido 1000 < d < 1250",
        "XPS Expandido con dióxido de carbono CO2 [ 0.034 W/[mK]]",
        "FU Entrevigado cerámico -Canto 250 mm",
        "Cámara de aire sin ventilar horizontal 5 cm",
        "Placa de yeso laminado [PYL] 750 < d < 900"
      ],
      "thicknesses": [
        0.01,
        0.05,
        0.065,
        0.06,
        0.25,
        0.05,
        0.015
      ],
      "solar_alpha": [
        0.6,
        0.6
      ],
      "lw_epsilon": [
        0.9,
        0.9
      ]
    },
    {
      "type": "Construction",
      "name": "MURO CAMARA SANITARIA",
      "materials": [
        "Betún fieltro o lámina",
        "1 pie LP métrico o catalán 40 mm< G < 60 mm"
      ],
      "thicknesses": [
        0.009,
        0.24
      ],
      "solar_alpha": [
        0.6,
        0.6
      ],
      "lw_epsilon": [
        0.9,
        0.9
      ]
    },
    {
      "type": "Construction",
      "name": "MURO EXTERIOR",
      "materials": [
        "Mortero de cemento o cal para albañilería y para revoco/enlucido 1000 < d < 1250",
        "EPS Poliestireno Expandido [ 0.037 W/[mK]]",
        "1 pie LP métrico o catalán 40 mm< G < 60 mm",
        "Mortero de cemento o cal para albañilería y para revoco/enlucido 1000 < d < 1250",
        "Cámara de aire sin ventilar horizontal 5 cm",
        "Placa de yeso laminado [PYL] 750 < d < 900",
        "Placa de yeso laminado [PYL] 750 < d < 900"
      ],
      "thicknesses": [
        0.03,
        0.14,
        0.24,
        0.01,
        0.05,
        0.015,
        0.015
      ],
      "solar_alpha": [
        0.6,
        0.6
      ],
      "lw_epsilon": [
        0.9,
        0.9
      ]
    },
    {
      "type": "Construction",
      "name": "SOLERA CAM SANITARIA",
      "materials": [
        "Hormigón en masa 2000 < d < 2300",
        "Cloruro de polivinilo [PVC]",
        "Arena y grava [1700 < d < 2200]"
      ],
      "thicknesses": [
        0.08,
        0.003,
        0.12
      ],
      "solar_alpha": [
        0.6,
        0.6
      ],
      "lw_epsilon": [
        0.9,
        0.9
      ]
    },
    {
      "type": "Construction",
      "name": "TABIQUE INTERIOR",
      "materials": [
        "Placa de yeso laminado [PYL] 750 < d < 900",
        "Placa de yeso laminado [PYL] 750 < d < 900",
        "MW Lana mineral [0.04 W/[mK]]",
        "Placa de yeso laminado [PYL] 750 < d < 900",
        "Placa de yeso laminado [PYL] 750 < d < 900"
      ],
      "thicknesses": [
        0.013,
        0.013,
        0.04,
        0.013,
        0.013
      ],
      "solar_alpha": [
        0.6,
        0.6
      ],
      "lw_epsilon": [
        0.9,
        0.9
      ]
    },
    {
      "type": "Opening_type",
      "name": "LUCERNARIO NORTE",
      "glazing": "VIRDIO NORTE",
      "frame": "HOR_Madera de densidad media alta",
      "glazing_fraction": 0.8,
      "frame_fraction": 0.2
    },
    {
      "type": "Opening_type",
      "name": "LUCERNARIO SUR",
      "glazing": "VIDRIO SUR",
      "frame": "HOR_Madera de densidad media alta",
      "glazing_fraction": 0.8,
      "frame_fraction": 0.2
    },
    {
      "type": "Opening_type",
      "name": "PUERTA DE ACCESO",
      "glazing": "VER_DC_4-12-4",
      "frame": "VER_Madera de densidad media alta",
      "glazing_fraction": 0.0,
      "frame_fraction": 1.0
    },
    {
      "type": "Opening_type",
      "name": "VENTANA TIPO ESTE",
      "glazing": "VIRDIO NORTE",
      "frame": "MARCO PVC PROPIO",
      "glazing_fraction": 0.75,
      "frame_fraction": 0.25
    },
    {
      "type": "Opening_type",
      "name": "VENTANA TIPO NORTE",
      "glazing": "VIRDIO NORTE",
      "frame": "MARCO PVC PROPIO",
      "glazing_fraction": 0.75,
      "frame_fraction": 0.25
    },
    {
      "type": "Opening_type",
      "name": "VENTANA TIPO OESTE",
      "glazing": "VIDRIO SUR",
      "frame": "MARCO PVC PROPIO",
      "glazing_fraction": 0.75,
      "frame_fraction": 0.25
    },
    {
      "type": "Opening_type",
      "name": "VENTANA TIPO SUR",
      "glazing": "VIDRIO SUR",
      "frame": "MARCO PVC PROPIO",
      "glazing_fraction": 0.75,
      "frame_fraction": 0.25
    },
    {
      "type": "Opening_type",
      "name": "LUCERNARIO ESTE",
      "glazing": "VIDRIO SUR",
      "frame": "HOR_Madera de densidad media alta",
      "glazing_fraction": 0.8,
      "frame_fraction": 0.2
    },
    {
      "type": "Construction",
      "name": "SOLERA CAM SANITARIA__P01_E01_FTER001",
      "materials": [
        "Hormigón en masa 2000 < d < 2300",
        "Cloruro de polivinilo [PVC]",
        "Arena y grava [1700 < d < 2200]"
      ],
      "thicknesses": [
        0.08,
        0.003,
        0.12
      ],
      "solar_alpha": [
        0.6,
        0.6
      ],
      "lw_epsilon": [
        0.9,
        0.9
      ]
    },
    {
      "type": "Day_schedule",
      "name": "dia_cargas",
      "time_steps": [
        25200,
        28800,
        28800
      ],
      "values": [
        1.0,
        0.5,
        1.0,
        0.5
      ],
      "interpolation": "STEP"
    },
    {
      "type": "Week_schedule",
      "name": "semana_cargas",
      "days_schedules": [
        "dia_cargas"
      ]
    },
    {
      "type": "Year_schedule",
      "name": "anual_cargas",
      "periods": [],
      "weeks_schedules": [
        "semana_cargas"
      ]
    },
    {
      "type": "Day_schedule",
      "name": "dia_calef",
      "time_steps": [
        25200,
        57600
      ],
      "values": [
        17,
        20,
        17
      ],
      "interpolation": "STEP"
    },
    {
      "type": "Week_schedule",
      "name": "semana_calef",
      "days_schedules": [
        "dia_calef"
      ]
    },
    {
      "type": "Year_schedule",
      "name": "anual_calef",
      "periods": [],
      "weeks_schedules": [
        "semana_calef"
      ]
    },
    {
      "type": "Day_schedule",
      "name": "dia_refrig",
      "time_steps": [
        25200,
        57600
      ],
      "values": [
        27,
        25,
        27
      ],
      "interpolation": "STEP"
    },
    {
      "type": "Week_schedule",
      "name": "semana_refrig",
      "days_schedules": [
        "dia_refrig"
      ]
    },
    {
      "type": "Year_schedule",
      "name": "anual_refrig",
      "periods": [],
      "weeks_schedules": [
        "semana_refrig"
      ]
    },
    {
      "type": "Day_schedule",
      "name": "dia_ventila",
      "time_steps": [
        25200,
        57600
      ],
      "values": [
        0.5,
        1.0,
        0.5
      ],
      "interpolation": "STEP"
    },
    {
      "type": "Week_schedule",
      "name": "semana_ventila",
      "days_schedules": [
        "dia_ventila"
      ]
    },
    {
      "type": "Year_schedule",
      "name": "anual_ventila",
      "periods": [],
      "weeks_schedules": [
        "semana_ventila"
      ]
    },
    {
      "type": "Building",
      "name": "Edificio",
      "azimuth": 0,
      "ref_point": [
        0,
        0,
        0
      ]
    },
    {
      "type": "Space_type",
      "name": "Tipo_residencial_generico",
      "input_variables": [
        "f = anual_cargas.values",
        "v = anual_ventila.values"
      ],
      "people_density": "0.03*f",
      "light_density": "2.2*f",
      "other_gains_density": "2.2*f",
      "infiltration": "0.332 + 0.358*v"
    },
    {
      "type": "Material",
      "name": "Terreno_generico",
      "conductivity": 2.0,
      "density": 2050.0,
      "specific_heat": 1840.0
    },
    {
      "type": "Space",
      "name": "P01_E01",
      "building": "Edificio",
      "spaces_type": "Tipo_residencial_generico",
      "floor_area": 64.0,
      "volume": 64.0
    },
    {
      "type": "Building_surface",
      "name": "P01_E01_FTER001",
      "surface_type": "UNDERGROUND",
      "spaces": "P01_E01",
      "construction": "SOLERA CAM SANITARIA__P01_E01_FTER001",
      "ground_material": "Terreno_generico",
      "exterior_perimeter_fraction": 1.0,
      "exterior_perimeter_wall_thickness": 0.3,
      "groundwater_depth": 0.0,
      "shape": "RECTANGLE",
      "ref_point": [
        0.0,
        8.0,
        -1.0
      ],
      "width": 8.0,
      "height": 8.0,
      "azimuth": 0.0,
      "altitude": -90.0
    },
    {
      "type": "Building_surface",
      "name": "P01_E01_PCT001",
      "surface_type": "EXTERIOR",
      "spaces": "P01_E01",
      "construction": "MURO CAMARA SANITARIA",
      "shape": "RECTANGLE",
      "ref_point": [
        0.0,
        0.0,
        -1.0
      ],
      "width": 8.0,
      "height": 1.0,
      "azimuth": 0.0,
      "altitude": 0.0
    },
    {
      "type": "Building_surface",
      "name": "P01_E01_PCT002",
      "surface_type": "EXTERIOR",
      "spaces": "P01_E01",
      "construction": "MURO CAMARA SANITARIA",
      "shape": "RECTANGLE",
      "ref_point": [
        8.0,
        0.0,
        -1.0
      ],
      "width": 8.0,
      "height": 1.0,
      "azimuth": 90.0,
      "altitude": 0.0
    },
    {
      "type": "Building_surface",
      "name": "P01_E01_PCT003",
      "surface_type": "EXTERIOR",
      "spaces": "P01_E01",
      "construction": "MURO CAMARA SANITARIA",
      "shape": "RECTANGLE",
      "ref_point": [
        8.0,
        8.0,
        -1.0
      ],
      "width": 8.0,
      "height": 1.0,
      "azimuth": 180.0,
      "altitude": 0.0
    },
    {
      "type": "Building_surface",
      "name": "P01_E01_PCT004",
      "surface_type": "EXTERIOR",
      "spaces": "P01_E01",
      "construction": "MURO CAMARA SANITARIA",
      "shape": "RECTANGLE",
      "ref_point": [
        0.0,
        8.0,
        -1.0
      ],
      "width": 8.0,
      "height": 1.0,
      "azimuth": -90.0,
      "altitude": 0.0
    },
    {
      "type": "Space",
      "name": "P02_E01",
      "building": "Edificio",
      "spaces_type": "Tipo_residencial_generico",
      "floor_area": 64.0,
      "volume": 192.0
    },
    {
      "type": "Building_surface",
      "name": "P02_E01_PE001",
      "surface_type": "EXTERIOR",
      "spaces": "P02_E01",
      "construction": "MURO EXTERIOR",
      "shape": "RECTANGLE",
      "ref_point": [
        0.0,
        1.0,
        0.0
      ],
      "width": 1.0,
      "height": 3.0,
      "azimuth": -90.0,
      "altitude": 0.0
    },
    {
      "type": "Building_surface",
      "name": "P02_E01_PE002",
      "surface_type": "EXTERIOR",
      "spaces": "P02_E01",
      "construction": "MURO EXTERIOR",
      "shape": "RECTANGLE",
      "ref_point": [
        0.0,
        0.0,
        0.0
      ],
      "width": 3.0,
      "height": 3.0,
      "azimuth": 0.0,
      "altitude": 0.0
    },
    {
      "type": "Building_surface",
      "name": "P02_E01_PE003",
      "surface_type": "EXTERIOR",
      "spaces": "P02_E01",
      "construction": "MURO EXTERIOR",
      "shape": "RECTANGLE",
      "ref_point": [
        3.0,
        0.0,
        0.0
      ],
      "width": 5.0,
      "height": 3.0,
      "azimuth": 0.0,
      "altitude": 0.0
    },
    {
      "type": "Building_surface",
      "name": "P02_E01_PE004",
      "surface_type": "EXTERIOR",
      "spaces": "P02_E01",
      "construction": "MURO EXTERIOR",
      "shape": "RECTANGLE",
      "ref_point": [
        8.0,
        0.0,
        0.0
      ],
      "width": 5.0,
      "height": 3.0,
      "azimuth": 90.0,
      "altitude": 0.0
    },
    {
      "type": "Building_surface",
      "name": "P02_E01_PE005",
      "surface_type": "EXTERIOR",
      "spaces": "P02_E01",
      "construction": "MURO EXTERIOR",
      "shape": "RECTANGLE",
      "ref_point": [
        8.0,
        5.0,
        0.0
      ],
      "width": 3.0,
      "height": 3.0,
      "azimuth": 90.0,
      "altitude": 0.0
    },
    {
      "type": "Building_surface",
      "name": "P02_E01_PE006",
      "surface_type": "EXTERIOR",
      "spaces": "P02_E01",
      "construction": "MURO EXTERIOR",
      "shape": "RECTANGLE",
      "ref_point": [
        8.0,
        8.0,
        0.0
      ],
      "width": 5.0,
      "height": 3.0,
      "azimuth": 180.0,
      "altitude": 0.0
    },
    {
      "type": "Building_surface",
      "name": "P02_E01_PE007",
      "surface_type": "EXTERIOR",
      "spaces": "P02_E01",
      "construction": "MURO EXTERIOR",
      "shape": "RECTANGLE",
      "ref_point": [
        3.0,
        8.0,
        0.0
      ],
      "width": 3.0,
      "height": 3.0,
      "azimuth": 180.0,
      "altitude": 0.0
    },
    {
      "type": "Building_surface",
      "name": "P02_E01_PE008",
      "surface_type": "EXTERIOR",
      "spaces": "P02_E01",
      "construction": "MURO EXTERIOR",
      "shape": "RECTANGLE",
      "ref_point": [
        0.0,
        8.0,
        0.0
      ],
      "width": 6.0,
      "height": 3.0,
      "azimuth": -90.0,
      "altitude": 0.0
    },
    {
      "type": "Building_surface",
      "name": "P02_E01_PE009",
      "surface_type": "EXTERIOR",
      "spaces": "P02_E01",
      "construction": "MURO EXTERIOR",
      "shape": "RECTANGLE",
      "ref_point": [
        0.0,
        2.0,
        0.0
      ],
      "width": 1.0,
      "height": 3.0,
      "azimuth": -90.0,
      "altitude": 0.0
    },
    {
      "type": "Building_surface",
      "name": "P02_E01_FI001",
      "surface_type": "INTERIOR",
      "spaces": [
        "P02_E01",
        "P01_E01"
      ],
      "construction": "FORJADO INTERIOR",
      "shape": "RECTANGLE",
      "ref_point": [
        0.0,
        8.0,
        0.0
      ],
      "width": 8.0,
      "height": 8.0,
      "azimuth": 0.0,
      "altitude": -90.0
    },
    {
      "type": "Space",
      "name": "P03_E01",
      "building": "Edificio",
      "spaces_type": "Tipo_residencial_generico",
      "floor_area": 64.0,
      "volume": 181.12
    },
    {
      "type": "Building_surface",
      "name": "P03_E01_ME001",
      "surface_type": "EXTERIOR",
      "spaces": "P03_E01",
      "construction": "MURO EXTERIOR",
      "ref_point": [
        0.0,
        0.0,
        3.0
      ],
      "azimuth": 0.0,
      "altitude": 0.0,
      "shape": "POLYGON",
      "x_polygon": [
        0.0,
        8.0,
        8.0,
        0.0
      ],
      "y_polygon": [
        0.0,
        0.0,
        1.5,
        1.5
      ]
    },
    {
      "type": "Building_surface",
      "name": "P03_E01_ME002",
      "surface_type": "EXTERIOR",
      "spaces": "P03_E01",
      "construction": "MURO EXTERIOR",
      "ref_point": [
        8.0,
        0.0,
        3.0
      ],
      "azimuth": 90.0,
      "altitude": 0.0,
      "shape": "POLYGON",
      "x_polygon": [
        0.0,
        8.0,
        8.0,
        0.0
      ],
      "y_polygon": [
        0.0,
        0.0,
        1.5,
        1.5
      ]
    },
    {
      "type": "Building_surface",
      "name": "P03_E01_ME003",
      "surface_type": "EXTERIOR",
      "spaces": "P03_E01",
      "construction": "MURO EXTERIOR",
      "ref_point": [
        8.0,
        8.0,
        3.0
      ],
      "azimuth": 180.0,
      "altitude": 0.0,
      "shape": "POLYGON",
      "x_polygon": [
        0.0,
        8.0,
        8.0,
        0.0
      ],
      "y_polygon": [
        0.0,
        0.0,
        1.5,
        1.5
      ]
    },
    {
      "type": "Building_surface",
      "name": "P03_E01_ME004",
      "surface_type": "EXTERIOR",
      "spaces": "P03_E01",
      "construction": "MURO EXTERIOR",
      "ref_point": [
        0.0,
        8.0,
        3.0
      ],
      "azimuth": -90.0,
      "altitude": 0.0,
      "shape": "POLYGON",
      "x_polygon": [
        0.0,
        8.0,
        8.0,
        0.0
      ],
      "y_polygon": [
        0.0,
        0.0,
        1.5,
        1.5
      ]
    },
    {
      "type": "Building_surface",
      "name": "P03_E01_FI001",
      "surface_type": "INTERIOR",
      "spaces": [
        "P03_E01",
        "P02_E01"
      ],
      "construction": "FORJADO INTERIOR",
      "shape": "RECTANGLE",
      "ref_point": [
        0.0,
        8.0,
        3.0
      ],
      "width": 8.0,
      "height": 8.0,
      "azimuth": 0.0,
      "altitude": -90.0
    },
    {
      "type": "Building_surface",
      "name": "P03_E01C004",
      "surface_type": "EXTERIOR",
      "spaces": "P03_E01",
      "construction": "CUBIERTA INCLINADA",
      "ref_point": [
        0.0,
        8.0,
        4.5
      ],
      "azimuth": -90.0,
      "altitude": 44.9595,
      "shape": "POLYGON",
      "x_polygon": [
        0.0,
        8.0,
        4.0083
      ],
      "y_polygon": [
        0.0,
        0.0,
        5.6529
      ]
    },
    {
      "type": "Building_surface",
      "name": "P03_E01C001",
      "surface_type": "EXTERIOR",
      "spaces": "P03_E01",
      "construction": "CUBIERTA INCLINADA",
      "ref_point": [
        0.0,
        0.0,
        4.5
      ],
      "azimuth": 0.0,
      "altitude": 44.9404,
      "shape": "POLYGON",
      "x_polygon": [
        0.0,
        8.0,
        3.9943
      ],
      "y_polygon": [
        0.0,
        0.0,
        5.651
      ]
    },
    {
      "type": "Building_surface",
      "name": "P03_E01C002",
      "surface_type": "EXTERIOR",
      "spaces": "P03_E01",
      "construction": "CUBIERTA INCLINADA",
      "ref_point": [
        8.0,
        0.0,
        4.5
      ],
      "azimuth": 90.0,
      "altitude": 45.0405,
      "shape": "POLYGON",
      "x_polygon": [
        0.0,
        8.0,
        3.9917
      ],
      "y_polygon": [
        0.0,
        0.0,
        5.6609
      ]
    },
    {
      "type": "Building_surface",
      "name": "P03_E01C003",
      "surface_type": "EXTERIOR",
      "spaces": "P03_E01",
      "construction": "CUBIERTA INCLINADA",
      "ref_point": [
        8.0,
        8.0,
        4.5
      ],
      "azimuth": 180.0,
      "altitude": 45.0595,
      "shape": "POLYGON",
      "x_polygon": [
        0.0,
        8.0,
        4.0057
      ],
      "y_polygon": [
        0.0,
        0.0,
        5.6627
      ]
    },
    {
      "type": "Opening",
      "name": "P02_E01_PE001_V",
      "surface": "P02_E01_PE001",
      "opening_type": "VENTANA TIPO OESTE",
      "shape": "RECTANGLE",
      "width": 0.98,
      "height": 2.2,
      "ref_point": [
        0.01,
        0.0
      ]
    },
    {
      "type": "Opening",
      "name": "P02_E01_PE003_V",
      "surface": "P02_E01_PE003",
      "opening_type": "VENTANA TIPO SUR",
      "shape": "RECTANGLE",
      "width": 4.98,
      "height": 2.2,
      "ref_point": [
        0.01,
        0.0
      ]
    },
    {
      "type": "Opening",
      "name": "P02_E01_PE005_V",
      "surface": "P02_E01_PE005",
      "opening_type": "VENTANA TIPO ESTE",
      "shape": "RECTANGLE",
      "width": 2.98,
      "height": 2.2,
      "ref_point": [
        0.01,
        0.0
      ]
    },
    {
      "type": "Opening",
      "name": "P02_E01_PE007_V",
      "surface": "P02_E01_PE007",
      "opening_type": "VENTANA TIPO NORTE",
      "shape": "RECTANGLE",
      "width": 2.98,
      "height": 2.2,
      "ref_point": [
        0.01,
        0.0
      ]
    },
    {
      "type": "Opening",
      "name": "P02_E01_PE009_V",
      "surface": "P02_E01_PE009",
      "opening_type": "PUERTA DE ACCESO",
      "shape": "RECTANGLE",
      "width": 0.98,
      "height": 2.2,
      "ref_point": [
        0.01,
        0.0
      ]
    },
    {
      "type": "Opening",
      "name": "P03_E01_ME001_V1",
      "surface": "P03_E01_ME001",
      "opening_type": "LUCERNARIO SUR",
      "shape": "RECTANGLE",
      "width": 1.0,
      "height": 1.5,
      "ref_point": [
        1.25,
        0.0
      ]
    },
    {
      "type": "Opening",
      "name": "P03_E01_ME002_V1",
      "surface": "P03_E01_ME002",
      "opening_type": "LUCERNARIO ESTE",
      "shape": "RECTANGLE",
      "width": 1.0,
      "height": 1.5,
      "ref_point": [
        2.75,
        0.0
      ]
    },
    {
      "type": "Opening",
      "name": "P03_E01_ME002_V2",
      "surface": "P03_E01_ME002",
      "opening_type": "LUCERNARIO ESTE",
      "shape": "RECTANGLE",
      "width": 1.0,
      "height": 1.5,
      "ref_point": [
        4.25,
        0.0
      ]
    },
    {
      "type": "Opening",
      "name": "P03_E01_ME003_V1",
      "surface": "P03_E01_ME003",
      "opening_type": "LUCERNARIO NORTE",
      "shape": "RECTANGLE",
      "width": 1.0,
      "height": 1.5,
      "ref_point": [
        5.05,
        0.0
      ]
    },
    {
      "type": "Opening",
      "name": "P03_E01C001_V1",
      "surface": "P03_E01C001",
      "opening_type": "LUCERNARIO SUR",
      "shape": "RECTANGLE",
      "width": 1.0,
      "height": 1.0,
      "ref_point": [
        1.25,
        0.0
      ]
    },
    {
      "type": "Opening",
      "name": "P03_E01C002_V1",
      "surface": "P03_E01C002",
      "opening_type": "LUCERNARIO ESTE",
      "shape": "RECTANGLE",
      "width": 1.0,
      "height": 1.0,
      "ref_point": [
        2.75,
        0.0
      ]
    },
    {
      "type": "Opening",
      "name": "P03_E01C002_V2",
      "surface": "P03_E01C002",
      "opening_type": "LUCERNARIO ESTE",
      "shape": "RECTANGLE",
      "width": 1.0,
      "height": 1.0,
      "ref_point": [
        4.25,
        0.0
      ]
    },
    {
      "type": "Opening",
      "name": "P03_E01C003_V1",
      "surface": "P03_E01C003",
      "opening_type": "LUCERNARIO NORTE",
      "shape": "RECTANGLE",
      "width": 1.0,
      "height": 1.0,
      "ref_point": [
        5.05,
        0.0
      ]
    },
    {
      "type": "HVAC_perfect_system",
      "name": "HVAC_P02_E01",
      "spaces": "P02_E01",
      "input_variables": [
        "tc = anual_calef.values",
        "tr = anual_refrig.values"
      ],
      "outdoor_air_flow": "0",
      "heating_setpoint": "tc",
      "cooling_setpoint": "tr",
      "system_on_off": "1"
    },
    {
      "type": "HVAC_perfect_system",
      "name": "HVAC_P03_E01",
      "spaces": "P03_E01",
      "input_variables": [
        "tc = anual_calef.values",
        "tr = anual_refrig.values"
      ],
      "outdoor_air_flow": "0",
      "heating_setpoint": "tc",
      "cooling_setpoint": "tr",
      "system_on_off": "1"
    },
    {
      "type": "File_met",
      "name": "Sevilla",
      "file_type": "MET",
      "file_name": "../mets/Sevilla.met"
    }
  ]
}
sim = osm.Simulation()
pro = sim.new_project("pro")
pro.read_dict(dic)
# Out:
# Reading project data from dictonary
# Reading completed.
# Checking project: Vivienda ejemplo 1
# Checking completed.

# %%
import datetime as dt

date = dt.datetime(2001,3,21,8,0,0)
#pro.show_3D(jupyter=True)
pro.show_3D_shadows(date,jupyter=True)
#pro.show_3D_shadows_animation(date,jupyter=True)

# %%
pro.simulate()
# Out:
# Calculating solar direct shadows ...
# Simulating Vivienda ejemplo 1: ...
# 100%|██████████| 8760/8760 [00:20<00:00, 417.85step/s, n_iter=2]
