# %% [markdown]
# ## ASHRAE 140-2023
#
# Section 8: CASE GC60b - Steay-State withntypical interior convective surface coefficient
#
# _opensimula: v 0.6_

# %%
import opensimula as osm

caseGC60b_dict = {
    "name": "Case GC60b",
    "time_step": 3600,
    "n_time_steps": 8760,
    "initial_time": "01/01/2001 00:00:00",
    "simulation_file_met": "GC30b_met",
    "shadow_calculation": "NO",
    "components": [
        {
            "type": "File_met",
            "name": "GC30b_met",
            "file_type": "TMY2",
            "file_name": "../../mets/GC30b.TM2"
        },
        {
            "type": "Material",
            "name": "Insulation",
            "conductivity": 0.0001,
            "density": 1,
            "specific_heat": 1
        },
        {
            "type": "Material",
            "name": "Ground",
            "conductivity": 1.9,
            "density": 1490,
            "specific_heat": 1800
        },
        {
            "type": "Construction",
            "name": "Adiabatic_Wall",
            "solar_alpha": [0,0],
            "lw_epsilon": [0,0],
            "materials": [
                "Insulation"
            ],
            "thicknesses": [
                1.0
            ]
        },
        {
            "type": "Construction",
            "name": "Floor_Slab",
            "solar_alpha": [0,0],
            "lw_epsilon": [0,0],
            "materials": [
                "Ground"
            ],
            "thicknesses": [
                0.01
            ]
        },
        {
            "type": "Space_type",
            "name": "no_gain_space",
            "people_density": "0",
            "light_density": "0",
            "other_gains_density": "0",
            "infiltration": "0"
        },
        {
            "type": "Building",
            "name": "Building",
            "azimuth": 0,
            "initial_temperature": 10
        },
        {
            "type": "Space",
            "name": "space_1",
            "building": "Building",
            "spaces_type": "no_gain_space",
            "floor_area": 144,
            "volume": 388.8,
            "furniture_weight": 0
        },
        {
            "type": "Building_surface",
            "name": "north_wall",
            "construction": "Adiabatic_Wall",
            "spaces": "space_1",
            "ref_point": [
                12,
                12,
                0
            ],
            "width": 12,
            "height": 2.7,
            "azimuth": 180,
            "altitude": 0,
            "h_cv": [
                100,
                7.95
            ]
        },
        {
            "type": "Building_surface",
            "name": "east_wall",
            "construction": "Adiabatic_Wall",
            "spaces": "space_1",
            "ref_point": [
                12,
                0,
                0
            ],
            "width": 12,
            "height": 2.7,
            "azimuth": 90,
            "altitude": 0,
            "h_cv": [
                100,
                7.95
            ]
        },
        {
            "type": "Building_surface",
            "name": "south_wall",
            "construction": "Adiabatic_Wall",
            "spaces": "space_1",
            "ref_point": [
                0,
                0,
                0
            ],
            "width": 12,
            "height": 2.7,
            "azimuth": 0,
            "altitude": 0,
            "h_cv": [
                100,
                7.95
            ]
        },
        {
            "type": "Building_surface",
            "name": "west_wall",
            "construction": "Adiabatic_Wall",
            "spaces": "space_1",
            "ref_point": [
                0,
                12,
                0
            ],
            "width": 12,
            "height": 2.7,
            "azimuth": -90,
            "altitude": 0,
            "h_cv": [
                100,
                7.95
            ]
        },
        {
            "type": "Building_surface",
            "name": "roof_wall",
            "construction": "Adiabatic_Wall",
            "spaces": "space_1",
            "ref_point": [
                0,
                0,
                2.7
            ],
            "width": 12,
            "height": 12,
            "azimuth": 0,
            "altitude": 90,
            "h_cv": [
                100,
                7.95
            ]
        },
        {
            "type": "Building_surface",
            "name": "floor_wall",
            "surface_type": "UNDERGROUND",
            "construction": "Floor_Slab",
            "ground_material": "Ground",
            "exterior_perimeter_wall_thickness": 0.24,
            "spaces": "space_1",
            "ref_point": [
                0,
                12,
                0
            ],
            "width": 12,
            "height": 12,
            "azimuth": 0,
            "altitude": -90,
            "h_cv": [
                100,
                7.95
            ]
        },
        {
            "type": "HVAC_perfect_system",
            "name": "system",
            "spaces": "space_1",
            "outdoor_air_flow": "0",
            "heating_setpoint": "30",
            "cooling_setpoint": "50",
            "system_on_off": "1"
        }
    ]
}


sim = osm.Simulation()
pro = sim.new_project("pro")
pro.read_dict(caseGC60b_dict)
pro.simulate()
# Out:
# Reading project data from dictonary
# Reading completed.
# Checking project: Case GC50b
# Checking completed.
# Simulating Case GC50b: ...
# 100%|██████████| 8760/8760 [00:06<00:00, 1301.42step/s, n_iter=3]

# %%
pro.component("floor_wall_vir_mat")
# Out:
# <h3>Component: floor_wall_vir_mat</h3><p><strong>Desciption: </strong>Material layer properties</p><strong>Parameters:</strong><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>key</th>
#       <th>type</th>
#       <th>value</th>
#       <th>unit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>name</td>
#       <td>Parameter_string</td>
#       <td>floor_wall_vir_mat</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>description</td>
#       <td>Parameter_string</td>
#       <td>Material layer properties</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>type</td>
#       <td>Parameter_string</td>
#       <td>Material</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>conductivity</td>
#       <td>Parameter_float</td>
#       <td>0.09949</td>
#       <td>W/(m·K)</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>density</td>
#       <td>Parameter_float</td>
#       <td>1.0</td>
#       <td>kg/m³</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>specific_heat</td>
#       <td>Parameter_float</td>
#       <td>1.0</td>
#       <td>J/(kg·K)</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>use_resistance</td>
#       <td>Parameter_boolean</td>
#       <td>False</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>thermal_resistance</td>
#       <td>Parameter_float</td>
#       <td>1.0</td>
#       <td>(m²·K)/W</td>
#     </tr>
#   </tbody>
# </table>

# %%
suelo = pro.component("floor_wall")
t_suelo = suelo.variable("T_s0")  
t_dentro = suelo.variable("T_s1")
t_aire = pro.component("space_1").variable("temperature")
sim.plot(pro.dates(),[t_suelo, t_dentro, t_aire])

# %%
sim.plot(pro.dates(),[pro.component("system").variable("Q_sensible")])

# %%
pro.component("floor_wall")
# Out:
# <h3>Component: floor_wall</h3><p><strong>Desciption: </strong>Building surface</p><strong>Parameters:</strong><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>key</th>
#       <th>type</th>
#       <th>value</th>
#       <th>unit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>name</td>
#       <td>Parameter_string</td>
#       <td>floor_wall</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>description</td>
#       <td>Parameter_string</td>
#       <td>Building surface</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>type</td>
#       <td>Parameter_string</td>
#       <td>Building_surface</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>azimuth</td>
#       <td>Parameter_float</td>
#       <td>0.0</td>
#       <td>°</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>altitude</td>
#       <td>Parameter_float</td>
#       <td>-90.0</td>
#       <td>°</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>shape</td>
#       <td>Parameter_options</td>
#       <td>RECTANGLE</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>width</td>
#       <td>Parameter_float</td>
#       <td>12.0</td>
#       <td>m</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>height</td>
#       <td>Parameter_float</td>
#       <td>12.0</td>
#       <td>m</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>ref_point</td>
#       <td>Parameter_float_list</td>
#       <td>[0.0, 12.0, 0.0]</td>
#       <td>m</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>x_polygon</td>
#       <td>Parameter_float_list</td>
#       <td>[0, 10, 10, 0]</td>
#       <td>m</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>y_polygon</td>
#       <td>Parameter_float_list</td>
#       <td>[0, 0, 10, 10]</td>
#       <td>m</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>construction</td>
#       <td>Parameter_component</td>
#       <td>Floor_Slab</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>spaces</td>
#       <td>Parameter_component_list</td>
#       <td>[space_1]</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>surface_type</td>
#       <td>Parameter_options</td>
#       <td>UNDERGROUND</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>h_cv</td>
#       <td>Parameter_float_list</td>
#       <td>[100.0, 7.95]</td>
#       <td>W/m²K</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>ground_material</td>
#       <td>Parameter_component</td>
#       <td>Ground</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>exterior_perimeter_fraction</td>
#       <td>Parameter_float</td>
#       <td>1.0</td>
#       <td>frac</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>exterior_perimeter_wall_thickness</td>
#       <td>Parameter_float</td>
#       <td>0.24</td>
#       <td>m</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>groundwater_depth</td>
#       <td>Parameter_float</td>
#       <td>0.0</td>
#       <td>m</td>
#     </tr>
#   </tbody>
# </table><br/><strong>Variables:</strong><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>key</th>
#       <th>description</th>
#       <th>unit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>E_dir_sunny</td>
#       <td></td>
#       <td>W/m²</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>E_dir</td>
#       <td></td>
#       <td>W/m²</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>E_dif_sunny</td>
#       <td></td>
#       <td>W/m²</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>E_dif</td>
#       <td></td>
#       <td>W/m²</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>T_s0</td>
#       <td></td>
#       <td>°C</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>T_s1</td>
#       <td></td>
#       <td>°C</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>q_cd0</td>
#       <td></td>
#       <td>W/m²</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>q_cd1</td>
#       <td></td>
#       <td>W/m²</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>p_0</td>
#       <td></td>
#       <td>W/m²</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>p_1</td>
#       <td></td>
#       <td>W/m²</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>q_cv0</td>
#       <td></td>
#       <td>W/m²</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>q_cv1</td>
#       <td></td>
#       <td>W/m²</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>q_sol0</td>
#       <td></td>
#       <td>W/m²</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>q_sol1</td>
#       <td></td>
#       <td>W/m²</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>q_swig0</td>
#       <td></td>
#       <td>W/m²</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>q_swig1</td>
#       <td></td>
#       <td>W/m²</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>q_lwig0</td>
#       <td></td>
#       <td>W/m²</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>q_lwig1</td>
#       <td></td>
#       <td>W/m²</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>q_lwt0</td>
#       <td></td>
#       <td>W/m²</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>q_lwt1</td>
#       <td></td>
#       <td>W/m²</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>T_rm</td>
#       <td></td>
#       <td>°C</td>
#     </tr>
#   </tbody>
# </table>

# %%
suelo = pro.component("floor_wall")
q_cd1 = suelo.variable("q_cd1")   
q_cv1 = suelo.variable("q_cv1")   
q_lw1 = suelo.variable("q_lwt1")

sim.plot(pro.dates(),[q_cd1, q_cv1, q_lw1])

# %%
print("q_floor: ",pro.component("floor_wall").variable("q_cd1").values[8759]*144)   
print("q_zone: ",pro.component("system").variable("Q_sensible").values[8759])  
print("U_ground: ",pro.component("floor_wall")._U_tot_) 
print("U_ground_dynamic: ",pro.component("floor_wall")._U_hat_ext_)
# Out:
# q_floor:  -2058.121816706105
# q_zone:  2058.669010030113
# U_ground:  0.714625631261029
# U_ground_dynamic:  0.45194815714832803
