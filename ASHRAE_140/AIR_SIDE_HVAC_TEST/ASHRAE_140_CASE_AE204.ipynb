# %% [markdown]
# ## ASHRAE 140-2023
#
# Section 11: CASE AE204  - High cooling, Wet-coil 1

# %%
import OpenSimula as osm

case_AE204 = {
    "name": "case_AE204",
    "time_step": 3600,
    "n_time_steps": 8760,
    "initial_time": "01/01/2001 00:00:00",
    "simulation_file_met": "T_ext_cte",
    "components": [
        {
            "type": "File_met",
            "name": "T_ext_cte",
            "file_type": "TMY2",
            "file_name": "../../mets/AE104.TM2"
        },    
        {
            "type": "Material",
            "name": "Insulation",
            "conductivity": 0.01,
            "density": 1,
            "specific_heat": 1
        },
        {
            "type": "Construction",
            "name": "Adiabatic_Wall",
            "solar_alpha": [0.1,0.6],
            "lw_epsilon": [0.9,0.9],
            "materials": [
                "Insulation"
            ],
            "thicknesses": [
                1.0
            ]
        },
        {
            "type": "Space_type",
            "name": "constant_gain_space",
            "people_density": "1",
            "people_sensible": 0,
            "people_latent": 12.21,
            "light_density": "0",
            "other_gains_density": "61.0625",
            "other_gains_radiant_fraction": 0,
            "infiltration": "0"
        },
        {
            "type": "Building",
            "name": "Building",
            "albedo": 0.2,
            "azimuth": 0,
            "shadow_calculation": "INSTANT"
        },
        {
            "type": "Space",
            "name": "space_1",
            "building": "Building",
            "space_type": "constant_gain_space",
            "floor_area": 48,
            "volume": 129.6,
            "furniture_weight": 0
        },
        {
            "type": "Exterior_surface",
            "name": "north_wall",
            "construction": "Adiabatic_Wall",
            "space": "space_1",
            "ref_point": [
                8,
                6,
                0
            ],
            "width": 8,
            "height": 2.7,
            "azimuth": 180,
            "altitude": 0,
            "h_cv": [
                24.17,
                3.16
            ]
        },
        {
            "type": "Exterior_surface",
            "name": "east_wall",
            "construction": "Adiabatic_Wall",
            "space": "space_1",
            "ref_point": [
                8,
                0,
                0
            ],
            "width": 6,
            "height": 2.7,
            "azimuth": 90,
            "altitude": 0,
             "h_cv": [
                24.17,
                3.16
            ]
        },
        {
            "type": "Exterior_surface",
            "name": "south_wall",
            "construction": "Adiabatic_Wall",
            "space": "space_1",
            "ref_point": [
                0,
                0,
                0
            ],
            "width": 8,
            "height": 2.7,
            "azimuth": 0,
            "altitude": 0,
             "h_cv": [
                24.17,
                3.16
            ]
        },
        {
            "type": "Exterior_surface",
            "name": "west_wall",
            "construction": "Adiabatic_Wall",
            "space": "space_1",
            "ref_point": [
                0,
                6,
                0
            ],
            "width": 6,
            "height": 2.7,
            "azimuth": -90,
            "altitude": 0,
             "h_cv": [
                24.17,
                3.16
            ]
        },
        {
            "type": "Exterior_surface",
            "name": "roof_wall",
            "construction": "Adiabatic_Wall",
            "space": "space_1",
            "ref_point": [
                0,
                0,
                2.7
            ],
            "width": 8,
            "height": 6,
            "azimuth": 0,
            "altitude": 90,
            "h_cv": [
                24.17,
                1.0
            ]
        },
        {
            "type": "Exterior_surface",
            "name": "floor_wall",
            "construction": "Adiabatic_Wall",
            "space": "space_1",
            "ref_point": [
                0,
                6,
                0
            ],
            "width": 8,
            "height": 6,
            "azimuth": 0,
            "altitude": -90,
            "h_cv": [
                24.17,
                4.13
            ]
        },
        {
            "type": "HVAC_fan_equipment",
            "name": "supply_fan",
            "nominal_air_flow":0.29422,
            "nominal_pressure": 498,
            "nominal_power": 201.45,
        },
        {
            "type": "HVAC_fan_equipment",
            "name": "return_fan",
            "nominal_air_flow":0.19615,
            "nominal_pressure": 249,
            "nominal_power": 67.15,
        },
        {
            "type": "HVAC_coil_equipment",
            "name": "coil",
            "nominal_air_flow": 0.29422,
            "nominal_heating_capacity": 0,
            "nominal_total_cooling_capacity": 7000,
            "nominal_sensible_cooling_capacity": 5230,
            "nominal_cooling_water_flow": 3.415e-4
        },
        {
            "type": "HVAC_SZW_system",
            "name": "system",
            "space": "space_1",
            "cooling_coil": "coil",
            "supply_fan": "supply_fan",
            "return_fan": "return_fan",
            "air_flow": 0.29422,
            "return_air_flow": 0.19615,
            "outdoor_air_fraction": 0.33333,
            "cooling_water_flow": 3.415e-4,
            "cooling_setpoint": "23.889",
            "heating_setpoint": "0",
            "system_on_off": "1",
            "water_flow_control": "PROPORTIONAL"
        }
    ]
}

sim = osm.Simulation()
pro = sim.new_project("pro")
pro.read_dict(case_AE204)
pro.simulate()
# Out:
# Reading project data from dictonary
# Reading completed.
# Checking project: case_AE204
# Checking completed.
# Calculating solar direct shadows ...
# Calculating solar diffuse shadows ...
# Simulating case_AE204: ...
# 10%: N_iter: 8.99
# 20%: N_iter: 9.00
# 30%: N_iter: 9.00
# 40%: N_iter: 9.00
# 50%: N_iter: 9.00
# 60%: N_iter: 9.00
# 70%: N_iter: 9.00
# 80%: N_iter: 9.00
# 90%: N_iter: 9.00
# 100%: N_iter: 9.00
# Simulation completed.

# %%
import pandas as pd
import psychrolib as sicro
sicro.SetUnitSystem(sicro.SI)
system = pro.component("system")
sys_df=system.variable_dataframe()
space_df=pro.component("space_1").variable_dataframe()

print("Q_sensible_zone: ", space_df["system_sensible_heat"][8759]/1000)
print("Q_latent_zone: ", space_df["system_latent_heat"][8759]/1000)
print("Q_sensible_system: ", sys_df["Q_sensible"][8759]/1000)
print("Q_latent_system: ", sys_df["Q_latent"][8759]/1000)

p = system.props["ATM_PRESSURE"]

T_odb = sys_df["T_OA"][8759]
T_owb = sys_df["T_OAwb"][8759]
w_o = sicro.GetHumRatioFromTWetBulb(T_odb,T_owb,p)
v_o = sicro.GetMoistAirVolume(T_odb,w_o,p)
h_o = sicro.GetMoistAirEnthalpy(T_odb,w_o)/1000

T_idb = sys_df["T_MA"][8759]
T_iwb = sys_df["T_MAwb"][8759]
w_i = sicro.GetHumRatioFromTWetBulb(T_idb,T_iwb,p)
v_i = sicro.GetMoistAirVolume(T_idb,w_i,p)
h_i = sicro.GetMoistAirEnthalpy(T_idb,w_i)/1000

T_supply = sys_df["T_SA"][8759]
w_supply = sys_df["w_SA"][8759]/1000
v_supply = sicro.GetMoistAirVolume(T_supply,w_supply,p)
h_supply = sicro.GetMoistAirEnthalpy(T_supply,w_supply)/1000

# Coil output
T_co = sys_df["T_CA"][8759]
w_co = sys_df["w_CA"][8759]/1000
v_co = sicro.GetMoistAirVolume(T_co,w_co,p)
h_co = sicro.GetMoistAirEnthalpy(T_co,w_co)/1000
print("Coil output HR(%): ",sicro.GetRelHumFromHumRatio(T_co,w_co,p)*100)

# Return air
T_ra = space_df["temperature"][8759]
w_ra = space_df["abs_humidity"][8759]/1000
v_ra = sicro.GetMoistAirVolume(T_ra,w_ra,p)
h_ra = sicro.GetMoistAirEnthalpy(T_ra,w_ra)/1000

m_su = sys_df["m_air_flow"][8759]
m_o = sys_df["outdoor_air_fraction"][8759]*m_su
m_r = m_su - m_o

# Return fan outlet
T_rao = sys_df["T_RA"][8759]
w_rao = w_ra
v_rao = sicro.GetMoistAirVolume(T_rao,w_rao,p)
h_rao = sicro.GetMoistAirEnthalpy(T_rao,w_rao)/1000

excel = pd.DataFrame()
excel["OA"] = [T_odb,w_o,v_o*1000,h_o,m_o]
excel["MA"] = [T_idb,w_i,v_i*1000,h_i,m_su]
excel["CO"] = [T_co,w_co,v_co*1000,h_co,m_su]
excel["SA"] = [T_supply,w_supply,v_supply*1000,h_supply,m_su]
excel["RA"] = [T_ra,w_ra,v_ra*1000,h_ra,m_r]
excel["RAO"] = [T_rao,w_rao,v_rao*1000,h_rao,m_r]

excel.to_clipboard()
excel
# Out:
# Q_sensible_zone:  -2.934218299361448
# Q_latent_zone:  -0.5867710213450812
# Q_sensible_system:  3.54733621301912
# Q_latent_system:  2.229526742765527
# Coil output HR(%):  98.41439945488628
#            OA          MA          CO          SA          RA         RAO
# 0   26.900000   25.087950   14.751932   15.338905   23.888455   24.181939
# 1    0.016766    0.012919    0.010307    0.010307    0.010995    0.010995
# 2  872.920302  862.423758  829.108808  830.799191  856.350897  857.196998
# 3   69.830992   58.152703   40.900649   41.502397   52.017658   52.318905
# 4    0.113717    0.341155    0.341155    0.341155    0.227437    0.227437

# %%
sys_df[["epsilon","epsilon_adp","F_load"]].tail(10)
# Out:
#        epsilon  epsilon_adp    F_load
# 8750  0.660026     0.990745  0.807106
# 8751  0.660026     0.990745  0.807106
# 8752  0.660026     0.990745  0.807106
# 8753  0.660026     0.990745  0.807106
# 8754  0.660026     0.990745  0.807106
# 8755  0.660026     0.990745  0.807106
# 8756  0.660026     0.990745  0.807106
# 8757  0.660026     0.990745  0.807106
# 8758  0.660026     0.990745  0.807106
# 8759  0.660026     0.990745  0.807106
