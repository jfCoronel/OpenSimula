# %% [markdown]
# ## ASHRAE 140-2023
#
# Section 11: CASE AE226  - Low cooling, Wet-coil 1 with Dry-bulb economizer

# %%
import OpenSimula as osm

case_AE226 = {
    "name": "case_AE226",
    "time_step": 3600,
    "n_time_steps": 8760,
    "initial_time": "01/01/2001 00:00:00",
    "simulation_file_met": "T_ext_cte",
    "components": [
        {
            "type": "File_met",
            "name": "T_ext_cte",
            "file_type": "TMY2",
            "file_name": "../../mets/AE106.TM2"
        },    
        {
            "type": "Material",
            "name": "Insulation",
            "conductivity": 0.01,
            "density": 1,
            "specific_heat": 1
        },
        {
            "type": "Construction",
            "name": "Adiabatic_Wall",
            "solar_alpha": [0.1,0.6],
            "lw_epsilon": [0.9,0.9],
            "materials": [
                "Insulation"
            ],
            "thicknesses": [
                1.0
            ]
        },
        {
            "type": "Space_type",
            "name": "constant_gain_space",
            "people_density": "1",
            "people_sensible": 0,
            "people_latent": 12.21,
            "light_density": "0",
            "other_gains_density": "30.521",
            "other_gains_radiant_fraction": 0,
            "infiltration": "0"
        },
        {
            "type": "Building",
            "name": "Building",
            "albedo": 0.2,
            "azimuth": 0,
            "shadow_calculation": "INSTANT"
        },
        {
            "type": "Space",
            "name": "space_1",
            "building": "Building",
            "space_type": "constant_gain_space",
            "floor_area": 48,
            "volume": 129.6,
            "furniture_weight": 0
        },
        {
            "type": "Exterior_surface",
            "name": "north_wall",
            "construction": "Adiabatic_Wall",
            "space": "space_1",
            "ref_point": [
                8,
                6,
                0
            ],
            "width": 8,
            "height": 2.7,
            "azimuth": 180,
            "altitude": 0,
            "h_cv": [
                24.17,
                3.16
            ]
        },
        {
            "type": "Exterior_surface",
            "name": "east_wall",
            "construction": "Adiabatic_Wall",
            "space": "space_1",
            "ref_point": [
                8,
                0,
                0
            ],
            "width": 6,
            "height": 2.7,
            "azimuth": 90,
            "altitude": 0,
             "h_cv": [
                24.17,
                3.16
            ]
        },
        {
            "type": "Exterior_surface",
            "name": "south_wall",
            "construction": "Adiabatic_Wall",
            "space": "space_1",
            "ref_point": [
                0,
                0,
                0
            ],
            "width": 8,
            "height": 2.7,
            "azimuth": 0,
            "altitude": 0,
             "h_cv": [
                24.17,
                3.16
            ]
        },
        {
            "type": "Exterior_surface",
            "name": "west_wall",
            "construction": "Adiabatic_Wall",
            "space": "space_1",
            "ref_point": [
                0,
                6,
                0
            ],
            "width": 6,
            "height": 2.7,
            "azimuth": -90,
            "altitude": 0,
             "h_cv": [
                24.17,
                3.16
            ]
        },
        {
            "type": "Exterior_surface",
            "name": "roof_wall",
            "construction": "Adiabatic_Wall",
            "space": "space_1",
            "ref_point": [
                0,
                0,
                2.7
            ],
            "width": 8,
            "height": 6,
            "azimuth": 0,
            "altitude": 90,
            "h_cv": [
                24.17,
                1.0
            ]
        },
        {
            "type": "Exterior_surface",
            "name": "floor_wall",
            "construction": "Adiabatic_Wall",
            "space": "space_1",
            "ref_point": [
                0,
                6,
                0
            ],
            "width": 8,
            "height": 6,
            "azimuth": 0,
            "altitude": -90,
            "h_cv": [
                24.17,
                4.13
            ]
        },
        {
            "type": "HVAC_fan_equipment",
            "name": "supply_fan",
            "nominal_air_flow":0.28862,
            "nominal_pressure": 498,
            "nominal_power": 201.45,
        },
        {
            "type": "HVAC_fan_equipment",
            "name": "return_fan",
            "nominal_air_flow":0.19241,
            "nominal_pressure": 249,
            "nominal_power": 67.15,
        },
        {
            "type": "HVAC_coil_equipment",
            "name": "coil",
            "nominal_air_flow": 0.28862,
            "nominal_heating_capacity": 0,
            "nominal_total_cooling_capacity": 7164,
            "nominal_sensible_cooling_capacity": 5272,
            "nominal_cooling_water_flow": 3.415e-4
        },
        {
            "type": "HVAC_SZW_system",
            "name": "system",
            "space": "space_1",
            "coolung_coil": "coil",
            "supply_fan": "supply_fan",
            "return_fan": "return_fan",
            "air_flow": 0.28862,
            "return_air_flow": 0.19241,
            "outdoor_air_fraction": 0.33333,
            "cooling_water_flow": 3.415e-4,
            "cooling_setpoint": "23.333",
            "heating_setpoint": "0",
            "system_on_off": "1",
            "water_flow_control": "PROPORTIONAL",
            "economizer": "TEMPERATURE",
        }
    ]
}

sim = osm.Simulation()
pro = sim.new_project("pro")
pro.read_dict(case_AE226)
pro.simulate()
# Out:
# Reading project data from dictonary
# ERROR: Component parameter coolung_coil does not exist
# Reading completed.
# Checking project: case_AE226
# ERROR: system, must define its coil equipment.
# Calculating solar direct shadows ...
# Calculating solar diffuse shadows ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 222
#     220 pro = sim.new_project("pro")
#     221 pro.read_dict(case_AE226)
# --> 222 pro.simulate()
#
# File ~/Documents/OpenSimula/src/OpenSimula/Project.py:382, in Project.simulate(self, show_percentage)
#     379         self._sim_.message(Message(msg,"ERROR"))
#     381 self._set_ordered_component_list_()
# --> 382 self._pre_simulation_(n, delta_t)
#     383 self._sim_df = pd.DataFrame({"dates":self.dates()})
#     384 self._sim_df["n_iterations"] = 0
#
# File ~/Documents/OpenSimula/src/OpenSimula/Project.py:423, in Project._pre_simulation_(self, n_time_steps, delta_t)
#     421 def _pre_simulation_(self, n_time_steps, delta_t):
#     422     for comp in self._ordered_component_list_:
# --> 423         comp.pre_simulation(n_time_steps, delta_t)
#
# File ~/Documents/OpenSimula/src/OpenSimula/components/HVAC_SZW_system.py:99, in HVAC_SZW_system.pre_simulation(self, n_time_steps, delta_t)
#      97 # Water flows and temperatures
#      98 self._cooling_water_flow = self.parameter("cooling_water_flow").value
# ---> 99 self._heating_water_flow = self.parameter("heating_water_flow").value
#     100 if self._c_coil:
#     101     self._cooling_F_water = self._cooling_water_flow/self._c_coil.parameter("nominal_cooling_water_flow").value
#
# AttributeError: 'NoneType' object has no attribute 'parameter'

# %%
import pandas as pd
import psychrolib as sicro
sicro.SetUnitSystem(sicro.SI)
system = pro.component("system")
sys_df=system.variable_dataframe()
space_df=pro.component("space_1").variable_dataframe()

print("Q_sensible_zone: ", space_df["system_sensible_heat"][8759]/1000)
print("Q_latent_zone: ", space_df["system_latent_heat"][8759]/1000)
print("Q_sensible_system: ", sys_df["Q_sensible"][8759]/1000)
print("Q_latent_system: ", sys_df["Q_latent"][8759]/1000)

p = system.props["ATM_PRESSURE"]

T_odb = sys_df["T_odb"][8759]
T_owb = sys_df["T_owb"][8759]
w_o = sicro.GetHumRatioFromTWetBulb(T_odb,T_owb,p)
v_o = sicro.GetMoistAirVolume(T_odb,w_o,p)
h_o = sicro.GetMoistAirEnthalpy(T_odb,w_o)/1000

T_idb = sys_df["T_idb"][8759]
T_iwb = sys_df["T_iwb"][8759]
w_i = sicro.GetHumRatioFromTWetBulb(T_idb,T_iwb,p)
v_i = sicro.GetMoistAirVolume(T_idb,w_i,p)
h_i = sicro.GetMoistAirEnthalpy(T_idb,w_i)/1000

T_supply = sys_df["T_supply"][8759]
w_supply = sys_df["w_supply"][8759]/1000
v_supply = sicro.GetMoistAirVolume(T_supply,w_supply,p)
h_supply = sicro.GetMoistAirEnthalpy(T_supply,w_supply)/1000

# Coil output
T_co = sys_df["T_fan_in"][8759]
w_co = sys_df["w_fan_in"][8759]/1000
v_co = sicro.GetMoistAirVolume(T_co,w_co,p)
h_co = sicro.GetMoistAirEnthalpy(T_co,w_co)/1000
print("Coil output HR(%): ",sicro.GetRelHumFromHumRatio(T_co,w_co,p)*100)

# Return air
T_ra = space_df["temperature"][8759]
w_ra = space_df["abs_humidity"][8759]/1000
v_ra = sicro.GetMoistAirVolume(T_ra,w_ra,p)
h_ra = sicro.GetMoistAirEnthalpy(T_ra,w_ra)/1000

m_su = sys_df["m_air_flow"][8759]
m_o = sys_df["outdoor_air_fraction"][8759]*m_su
m_r =  (1-float(system.parameter("outdoor_air_fraction").value))*m_su

# Return fan outlet
T_rao = sys_df["T_return"][8759]
w_rao = w_ra
v_rao = sicro.GetMoistAirVolume(T_rao,w_rao,p)
h_rao = sicro.GetMoistAirEnthalpy(T_rao,w_rao)/1000

excel = pd.DataFrame()
excel["OA"] = [T_odb,w_o,v_o*1000,h_o,m_o]
excel["MA"] = [T_idb,w_i,v_i*1000,h_i,m_su]
excel["CO"] = [T_co,w_co,v_co*1000,h_co,m_su]
excel["SA"] = [T_supply,w_supply,v_supply*1000,h_supply,m_su]
excel["RA"] = [T_ra,w_ra,v_ra*1000,h_ra,m_r]
excel["RAO"] = [T_rao,w_rao,v_rao*1000,h_rao,m_r]

excel.to_clipboard()
excel
# Out:
# Q_sensible_zone:  -1.4626261988314053
# Q_latent_zone:  -0.5860799999999976
# Q_sensible_system:  1.6187932996917844
# Q_latent_system:  2.1396828326802786
# Coil output HR(%):  99.32201505350744
#            OA          MA          CO          SA          RA         RAO
# 0   23.000000   23.000000   18.205512   18.802160   23.333000   23.631322
# 1    0.015560    0.015565    0.013015    0.013015    0.013714    0.013714
# 2  859.947999  859.954453  842.649020  844.374625  858.421481  859.285228
# 3   62.719260   62.731431   51.306964   51.921636   58.365896   58.673617
# 4    0.335623    0.335623    0.335623    0.335623    0.223750    0.223750

# %%
sys_df[["epsilon","epsilon_adp","F_load"]].tail(10)
# Out:
#        epsilon  epsilon_adp    F_load
# 8750  0.688596     0.998987  0.452816
# 8751  0.688596     0.998987  0.452816
# 8752  0.688596     0.998987  0.452816
# 8753  0.688596     0.998987  0.452816
# 8754  0.688596     0.998987  0.452816
# 8755  0.688596     0.998987  0.452816
# 8756  0.688596     0.998987  0.452816
# 8757  0.688596     0.998987  0.452816
# 8758  0.688596     0.998987  0.452816
# 8759  0.688596     0.998987  0.452816
