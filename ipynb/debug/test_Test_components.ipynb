# %%
import OpenSimula.Simulation as Simulation

p1_dic = {
    "name": "project 1",
    "components": [
        {
            "type": "Test_component",
            "name": "comp 1",
            "boolean": True,
            "string": "Hola mundo",
            "int": 24,
            "float": 34.5,
            "options": "Two",
            "boolean_list": [True, True],
            "string_list": ["Hola 1", "Hola 2"],
            "int_list": [1, 2],
            "float_list": [1.1, 2.1],
            "options_list": ["Two", "Two"],
        },
        {
            "type": "Test_component",
            "name": "comp 2",
            "boolean": True,
            "string": "Hola mundo",
            "int": 24,
            "float": 34.6,
            "options": "Two",
            "component": "comp 1",
            "variable": "t_1 = comp 1.t"
        },
    ],
}

p2_dic = {
    "name": "project 2",
    "components": [
        {
            "type": "Test_component",
            "name": "comp 3",
            "component": "project 1->comp 1",
            "component_list": ["project 1->comp 1", "project 1->comp 2"],
            "variable": "t_1 = project 1->comp 1.t",
            "variable_list": ["t_2 = project 1->comp 1.t","t_3 = project 1->comp 2.t"],
            "math_exp": "4 * t_1 ",
            "math_exp_list": ["6 * t_2 ","ln(23)"]
        }
    ],
}

# %%
sim = Simulation()
p1 = sim.new_project("p1")
p1.read_dict(p1_dic)
p2 = sim.new_project("p2")
p2.read_dict(p2_dic)
sim
# Out:
# Reading project data from dictonary
# Reading completed.
# Checking project: project 1
# Checking completed.
# Reading project data from dictonary
# Reading completed.
# Checking project: project 2
# Checking completed.
# <h3>Simulation projects:</h3><ul><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>description</th>
#       <th>time_step</th>
#       <th>n_time_steps</th>
#       <th>initial_time</th>
#       <th>daylight_saving</th>
#       <th>daylight_saving_start_time</th>
#       <th>daylight_saving_end_time</th>
#       <th>n_max_iteration</th>
#       <th>simulation_order</th>
#       <th>simulation_file_met</th>
#       <th>shadow_calculation</th>
#       <th>albedo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>project 1</td>
#       <td>Description of the project</td>
#       <td>3600</td>
#       <td>8760</td>
#       <td>01/01/2001 00:00:00</td>
#       <td>False</td>
#       <td>25/03/2001 02:00:00</td>
#       <td>28/10/2001 02:00:00</td>
#       <td>1000</td>
#       <td>[Space_type, Building_surface, Solar_surface, Opening, Space, Building, HVAC_MZW_system, HVAC_perfect_system, HVAC_DX_system, HVAC_SZW_system, Calculator]</td>
#       <td>not_defined</td>
#       <td>INSTANT</td>
#       <td>0.2</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>project 2</td>
#       <td>Description of the project</td>
#       <td>3600</td>
#       <td>8760</td>
#       <td>01/01/2001 00:00:00</td>
#       <td>False</td>
#       <td>25/03/2001 02:00:00</td>
#       <td>28/10/2001 02:00:00</td>
#       <td>1000</td>
#       <td>[Space_type, Building_surface, Solar_surface, Opening, Space, Building, HVAC_MZW_system, HVAC_perfect_system, HVAC_DX_system, HVAC_SZW_system, Calculator]</td>
#       <td>not_defined</td>
#       <td>INSTANT</td>
#       <td>0.2</td>
#     </tr>
#   </tbody>
# </table>

# %%
p1
# Out:
# <h3>Project: project 1</h3><p>Description of the project</p><strong>Parameters:</strong><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>key</th>
#       <th>type</th>
#       <th>value</th>
#       <th>unit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>name</td>
#       <td>Parameter_string</td>
#       <td>project 1</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>description</td>
#       <td>Parameter_string</td>
#       <td>Description of the project</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>time_step</td>
#       <td>Parameter_int</td>
#       <td>3600</td>
#       <td>s</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>n_time_steps</td>
#       <td>Parameter_int</td>
#       <td>8760</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>initial_time</td>
#       <td>Parameter_string</td>
#       <td>01/01/2001 00:00:00</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>daylight_saving</td>
#       <td>Parameter_boolean</td>
#       <td>False</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>daylight_saving_start_time</td>
#       <td>Parameter_string</td>
#       <td>25/03/2001 02:00:00</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>daylight_saving_end_time</td>
#       <td>Parameter_string</td>
#       <td>28/10/2001 02:00:00</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>n_max_iteration</td>
#       <td>Parameter_int</td>
#       <td>1000</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>simulation_order</td>
#       <td>Parameter_string_list</td>
#       <td>[Space_type, Building_surface, Solar_surface, Opening, Space, Building, HVAC_MZW_system, HVAC_perfect_system, HVAC_DX_system, HVAC_SZW_system, Calculator]</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>simulation_file_met</td>
#       <td>Parameter_component</td>
#       <td>not_defined</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>shadow_calculation</td>
#       <td>Parameter_options</td>
#       <td>INSTANT</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>albedo</td>
#       <td>Parameter_float</td>
#       <td>0.2</td>
#       <td>frac</td>
#     </tr>
#   </tbody>
# </table><br/><strong>Components list:</strong><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>type</th>
#       <th>description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>comp 1</td>
#       <td>Test_component</td>
#       <td>Dummy component for testing</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>comp 2</td>
#       <td>Test_component</td>
#       <td>Dummy component for testing</td>
#     </tr>
#   </tbody>
# </table>

# %%
p1.simulate()
p1.component("comp 1")
# Out:
# Calculating solar direct shadows ...
# Simulating project 1: ...
# 100%|██████████| 8760/8760 [00:03<00:00, 2707.78step/s, n_iter=1]
# <h3>Component: comp 1</h3><p><strong>Desciption: </strong>Dummy component for testing</p><strong>Parameters:</strong><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>key</th>
#       <th>type</th>
#       <th>value</th>
#       <th>unit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>name</td>
#       <td>Parameter_string</td>
#       <td>comp 1</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>description</td>
#       <td>Parameter_string</td>
#       <td>Dummy component for testing</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>type</td>
#       <td>Parameter_string</td>
#       <td>Test_component</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>boolean</td>
#       <td>Parameter_boolean</td>
#       <td>True</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>string</td>
#       <td>Parameter_string</td>
#       <td>Hola mundo</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>int</td>
#       <td>Parameter_int</td>
#       <td>24</td>
#       <td>h</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>float</td>
#       <td>Parameter_float</td>
#       <td>34.5</td>
#       <td>m</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>options</td>
#       <td>Parameter_options</td>
#       <td>Two</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>component</td>
#       <td>Parameter_component</td>
#       <td>not_defined</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>variable</td>
#       <td>Parameter_variable</td>
#       <td>not_defined = component.variable</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>math_exp</td>
#       <td>Parameter_math_exp</td>
#       <td>0.0</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>boolean_list</td>
#       <td>Parameter_boolean_list</td>
#       <td>[True, True]</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>string_list</td>
#       <td>Parameter_string_list</td>
#       <td>[Hola 1, Hola 2]</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>int_list</td>
#       <td>Parameter_int_list</td>
#       <td>[1, 2]</td>
#       <td>h</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>float_list</td>
#       <td>Parameter_float_list</td>
#       <td>[1.1, 2.1]</td>
#       <td>m</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>options_list</td>
#       <td>Parameter_options_list</td>
#       <td>[Two, Two]</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>component_list</td>
#       <td>Parameter_component_list</td>
#       <td>[not_defined, not_defined]</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>variable_list</td>
#       <td>Parameter_variable_list</td>
#       <td>[not_defined = component.variable]</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>math_exp_list</td>
#       <td>Parameter_math_exp_list</td>
#       <td>[0.0]</td>
#       <td></td>
#     </tr>
#   </tbody>
# </table><br/><strong>Variables:</strong><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>key</th>
#       <th>description</th>
#       <th>unit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>t</td>
#       <td></td>
#       <td>s</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>exp_1</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>exp_2</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>exp_3</td>
#       <td></td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>

# %%
p1.component("comp 2")
# Out:
# <h3>Component: comp 2</h3><p><strong>Desciption: </strong>Dummy component for testing</p><strong>Parameters:</strong><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>key</th>
#       <th>type</th>
#       <th>value</th>
#       <th>unit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>name</td>
#       <td>Parameter_string</td>
#       <td>comp 2</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>description</td>
#       <td>Parameter_string</td>
#       <td>Dummy component for testing</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>type</td>
#       <td>Parameter_string</td>
#       <td>Test_component</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>boolean</td>
#       <td>Parameter_boolean</td>
#       <td>True</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>string</td>
#       <td>Parameter_string</td>
#       <td>Hola mundo</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>int</td>
#       <td>Parameter_int</td>
#       <td>24</td>
#       <td>h</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>float</td>
#       <td>Parameter_float</td>
#       <td>34.6</td>
#       <td>m</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>options</td>
#       <td>Parameter_options</td>
#       <td>Two</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>component</td>
#       <td>Parameter_component</td>
#       <td>comp 1</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>variable</td>
#       <td>Parameter_variable</td>
#       <td>t_1 = comp 1.t</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>math_exp</td>
#       <td>Parameter_math_exp</td>
#       <td>0.0</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>boolean_list</td>
#       <td>Parameter_boolean_list</td>
#       <td>[True, False]</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>string_list</td>
#       <td>Parameter_string_list</td>
#       <td>[Hello World 1, Hello World 2]</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>int_list</td>
#       <td>Parameter_int_list</td>
#       <td>[50, 100]</td>
#       <td>h</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>float_list</td>
#       <td>Parameter_float_list</td>
#       <td>[0.1, 0.2]</td>
#       <td>m</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>options_list</td>
#       <td>Parameter_options_list</td>
#       <td>[One, Two]</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>component_list</td>
#       <td>Parameter_component_list</td>
#       <td>[not_defined, not_defined]</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>variable_list</td>
#       <td>Parameter_variable_list</td>
#       <td>[not_defined = component.variable]</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>math_exp_list</td>
#       <td>Parameter_math_exp_list</td>
#       <td>[0.0]</td>
#       <td></td>
#     </tr>
#   </tbody>
# </table><br/><strong>Variables:</strong><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>key</th>
#       <th>description</th>
#       <th>unit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>t</td>
#       <td></td>
#       <td>s</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>exp_1</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>exp_2</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>exp_3</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>t_1</td>
#       <td></td>
#       <td>s</td>
#     </tr>
#   </tbody>
# </table>

# %%
p2.simulate()
# Out:
# Calculating solar direct shadows ...
# Simulating project 2: ...
#   0%|          | 0/8760 [00:00<?, ?step/s, n_iter=1]
# 100%|██████████| 8760/8760 [00:03<00:00, 2451.82step/s, n_iter=1]

# %%
p2.component("comp 3")
# Out:
# <h3>Component: comp 3</h3><p><strong>Desciption: </strong>Dummy component for testing</p><strong>Parameters:</strong><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>key</th>
#       <th>type</th>
#       <th>value</th>
#       <th>unit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>name</td>
#       <td>Parameter_string</td>
#       <td>comp 3</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>description</td>
#       <td>Parameter_string</td>
#       <td>Dummy component for testing</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>type</td>
#       <td>Parameter_string</td>
#       <td>Test_component</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>boolean</td>
#       <td>Parameter_boolean</td>
#       <td>False</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>string</td>
#       <td>Parameter_string</td>
#       <td>Hello World</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>int</td>
#       <td>Parameter_int</td>
#       <td>100</td>
#       <td>h</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>float</td>
#       <td>Parameter_float</td>
#       <td>0.1</td>
#       <td>m</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>options</td>
#       <td>Parameter_options</td>
#       <td>One</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>component</td>
#       <td>Parameter_component</td>
#       <td>project 1-&gt;comp 1</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>variable</td>
#       <td>Parameter_variable</td>
#       <td>t_1 = project 1-&gt;comp 1.t</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>math_exp</td>
#       <td>Parameter_math_exp</td>
#       <td>4 * t_1</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>boolean_list</td>
#       <td>Parameter_boolean_list</td>
#       <td>[True, False]</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>string_list</td>
#       <td>Parameter_string_list</td>
#       <td>[Hello World 1, Hello World 2]</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>int_list</td>
#       <td>Parameter_int_list</td>
#       <td>[50, 100]</td>
#       <td>h</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>float_list</td>
#       <td>Parameter_float_list</td>
#       <td>[0.1, 0.2]</td>
#       <td>m</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>options_list</td>
#       <td>Parameter_options_list</td>
#       <td>[One, Two]</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>component_list</td>
#       <td>Parameter_component_list</td>
#       <td>[project 1-&gt;comp 1, project 1-&gt;comp 2]</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>variable_list</td>
#       <td>Parameter_variable_list</td>
#       <td>[t_2 = project 1-&gt;comp 1.t, t_3 = project 1-&gt;comp 2.t]</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>math_exp_list</td>
#       <td>Parameter_math_exp_list</td>
#       <td>[6 * t_2 , ln(23)]</td>
#       <td></td>
#     </tr>
#   </tbody>
# </table><br/><strong>Variables:</strong><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>key</th>
#       <th>description</th>
#       <th>unit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>t</td>
#       <td></td>
#       <td>s</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>exp_1</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>exp_2</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>exp_3</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>t_1</td>
#       <td></td>
#       <td>s</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>t_2</td>
#       <td></td>
#       <td>s</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>t_3</td>
#       <td></td>
#       <td>s</td>
#     </tr>
#   </tbody>
# </table>

# %%
#p2.component("comp 3").parameter("boolean_list").value  
p2.component("comp 3").parameter("math_exp_list").value = "[6*t +4 , t^2]"
p2.component("comp 3").parameter("math_exp_list").value
# Out:
# ['[6*t +4 , t^2]']

# %%
sim.message_list()
# Out:
# [<OpenSimula.Message.Message at 0x123a8ae40>,
#  <OpenSimula.Message.Message at 0x123afd810>,
#  <OpenSimula.Message.Message at 0x123afd950>,
#  <OpenSimula.Message.Message at 0x123add0f0>,
#  <OpenSimula.Message.Message at 0x123add810>,
#  <OpenSimula.Message.Message at 0x123b04050>,
#  <OpenSimula.Message.Message at 0x123ae0f30>,
#  <OpenSimula.Message.Message at 0x123ae1150>,
#  <OpenSimula.Message.Message at 0x1239cfe50>,
#  <OpenSimula.Message.Message at 0x123b84150>,
#  <OpenSimula.Message.Message at 0x123af74d0>,
#  <OpenSimula.Message.Message at 0x10a22f2f0>]

# %%
p1.component_editor("Test_component")
# Out:
#         <iframe
#             width="100%"
#             height="600"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
